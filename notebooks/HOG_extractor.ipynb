# %%
from skimage.io import imread, imshow

from skimage import exposure
import pandas as pd
import numpy as np
import cv2
import pickle
from numpy import savetxt
from hog_extractor import HogFeaturesExtractor

# %%
img = imread('C:/Users/gabriele.ferrario/Desktop/progetto_AML/visual/img/2.jpg')
imshow(img)
print(img.shape)
# Out:
# (199, 192, 3)

# %%
features_extractor= HogFeaturesExtractor()
f_tmp = features_extractor.extract(img)

# %%
f_tmp[14]
# Out:
# 0.09192990360610237
